# %%
from faker import Faker
fake = Faker()

# %%
print(fake.name())

# %%
print(fake.email())
print(fake.country())
print(fake.name())
print(fake.text())
print(fake.latitude(), fake.longitude())
print(fake.url())

# %%
print(fake.text(max_nb_chars=1000))

# %%
import requests

# %%
data = [
  {
    "topic": "The Social and Personal Importance of Mental Health Awareness",
    "tags": [
      "psychology",
      "mental-health",
      "society",
      "well-being",
      "awareness"
    ],
    "content": "Mental health awareness is critical because it challenges the stigma surrounding psychological struggles, encourages individuals to seek help, and improves overall societal well-being. Historically, mental health conditions were often misunderstood, leading to isolation and discrimination against those affected. Increased awareness campaigns, education, and open dialogue normalize the fact that mental health is a spectrum, just like physical health, and that conditions like depression, anxiety, and PTSD are treatable. On a personal level, awareness allows individuals to recognize early signs of distress in themselves and others, leading to earlier intervention, which is crucial for recovery. On a societal level, poor mental health leads to staggering economic costs due to lost productivity, increased healthcare spending, and absenteeism. By prioritizing awareness and reducing stigma, employers, schools, and communities can foster a supportive environment where people feel safe discussing their struggles, accessing resources, and maintaining productive, fulfilling lives. This shift transforms mental health from a private struggle into a public health priority, leading to better outcomes for everyone."
  },
  {
    "topic": "Explaining How Habits Are Formed and Changed",
    "tags": [
      "psychology",
      "behavior",
      "self-improvement",
      "neuroscience",
      "productivity"
    ],
    "content": "Habits are automatic behaviors developed through repetition, allowing the brain to outsource decisions to the subconscious mind, thereby conserving cognitive energy. The formation of a habit is best described by the 'Habit Loop,' a four-step psychological process identified by researchers. The loop consists of: 1. **The Cue:** A trigger that tells your brain to go into automatic mode and execute a specific habit (e.g., seeing a coffee machine). 2. **The Craving:** The motivational force behind the habit; the desire for the resulting change in state (e.g., the craving for caffeine). 3. **The Response:** The habit itself, the physical or mental action (e.g., pouring and drinking the coffee). 4. **The Reward:** The positive feeling or benefit that satisfies the craving and reinforces the loop (e.g., feeling alert). To **change a bad habit**, the most effective strategy is not to eliminate the cue or the craving entirely, but to **substitute a new response** that delivers a similar reward. For **forming a new habit**, techniques like 'Temptation Bundling' (pairing a desired action with an undesired but necessary one) and the 'Two-Minute Rule' (starting a habit by making it take less than two minutes) are highly effective at overcoming the initial friction and embedding the new behavior into the loop."
  },
  {
    "topic": "Analyzing the Impact of Social Media on Attention Span",
    "tags": [
      "social-media",
      "psychology",
      "cognitive-science",
      "technology",
      "society"
    ],
    "content": "Social media platforms, designed to maximize user engagement, utilize features that fundamentally challenge the brain's ability to maintain sustained attention. The constant stream of novel information, short-form video content, immediate notifications, and the 'endless scroll' mechanism train the brain to prefer rapid context-switching over deep focus. This process conditions the brain to seek frequent, small dopamine hits, making it increasingly difficult to engage in tasks that require long periods of uninterrupted concentration, such as reading a book, performing complex work, or listening actively. While there is debate on whether the *average* human attention span is truly shrinking, there is strong evidence that **digital attention spans** are becoming more fragmented. The key impact is a reduction in **attentional filtering** (the ability to ignore distractions) and an increase in **task switching**, which significantly reduces productivity and the quality of deep, cognitive work. Counteracting this requires intentional practices like digital detoxes, scheduling focused work blocks, and proactively disabling notifications to retrain the mind for sustained engagement."
  },
  {
    "topic": "The Importance of Sleep for Cognitive Performance and Health",
    "tags": [
      "sleep",
      "health",
      "neuroscience",
      "productivity",
      "cognition"
    ],
    "content": "Sleep is not merely a period of rest; it is an active biological necessity critical for both physical restoration and peak cognitive performance. During sleep, the brain performs essential maintenance and consolidation tasks. **Memory Consolidation** is a primary function, where short-term memories are replayed and integrated into long-term storage networks, which is why a good night's sleep is essential after learning new information. Secondly, sleep allows for the **clearance of metabolic waste products** that build up in the brain during waking hours, most notably amyloid-beta, which is implicated in neurodegenerative diseases. From a cognitive perspective, chronic sleep deprivation severely impairs **executive functions**, including decision-making, problem-solving, emotional regulation, and attention. Even small deficits can lead to slower reaction times and impaired judgment, equivalent to being legally impaired. Prioritizing adequate, high-quality sleep (typically 7-9 hours for adults) is the single most effective, natural way to boost learning, mood, immune function, and professional performance. Disruptions to the natural circadian rhythm, common in modern life, significantly undermine all these processes."
  },
  {
    "topic": "Effective Techniques for Managing and Mitigating Stress",
    "tags": [
      "stress",
      "health",
      "well-being",
      "psychology",
      "self-care"
    ],
    "content": "Effective stress management involves a combination of physiological and psychological techniques aimed at down-regulating the body's 'fight-or-flight' response. The chronic activation of this stress response (releasing cortisol and adrenaline) is detrimental to long-term health. **Mindfulness and Meditation** are powerful psychological tools that teach individuals to observe stressful thoughts and feelings without judgment, creating a mental distance between the trigger and the reaction, thereby lowering overall anxiety. **Physical Exercise** is a core component, as it metabolizes excess stress hormones and releases endorphins, acting as a natural mood stabilizer. **Proper Sleep and Nutrition** underpin all stress resilience; sleep deprivation lowers the stress threshold, making minor irritations feel overwhelming. **Cognitive Restructuring** is a technique that involves identifying and challenging negative or catastrophic thought patterns that fuel anxiety, replacing them with more balanced and realistic perspectives. Finally, **Time Management** and setting clear boundaries (learning to say 'no') reduces the feeling of being overwhelmed by workload. A multi-faceted approach, incorporating daily practices rather than crisis intervention, is the key to maintaining a healthy and resilient response to life's inevitable pressures."
  },
  {
    "topic": "The Dynamics of Decision-Making Under Uncertainty",
    "tags": [
      "psychology",
      "decision-theory",
      "risk",
      "cognitive-bias",
      "uncertainty"
    ],
    "content": "Decision-making under uncertainty involves choosing a course of action when the outcome is unknown, the probability of different outcomes cannot be precisely quantified, or when the information available is incomplete. This area is heavily studied in economics, psychology, and management science. One of the most common psychological phenomena is **Prospect Theory**, which demonstrates that people tend to be risk-averse when evaluating potential gains but risk-seeking when evaluating potential losses. This asymmetry (the pain of loss outweighs the pleasure of an equivalent gain) significantly biases decisions. **Cognitive Biases**, such as the 'Confirmation Bias' (seeking information that supports existing beliefs) and the 'Anchoring Effect' (over-relying on the first piece of information received), further distort rational judgment. To improve decision-making under uncertainty, strategies include: 1. **Framing the Problem:** Clearly defining the worst-case, best-case, and most-likely scenarios. 2. **Using Expected Value:** Calculating the weighted average of all possible outcomes by their probability. 3. **Seeking Diverse Input:** Actively soliciting perspectives from people who hold different views to counteract confirmation bias. The goal is not to eliminate uncertainty, but to quantify and manage the known risks through a structured, analytical process rather than relying on intuition alone."
  },
  {
    "topic": "Role of Education in Facilitating Social Mobility",
    "tags": [
      "society",
      "economics",
      "education",
      "social-justice",
      "policy"
    ],
    "content": "Education is widely recognized as one of the most powerful catalysts for social mobility—the movement of individuals or families from one social stratum to another. High-quality education provides individuals from disadvantaged backgrounds with the human capital (knowledge, skills, and credentials) necessary to compete for higher-paying, higher-status jobs. It acts as a **leveler** by providing a mechanism to overcome structural disadvantages inherited at birth. For example, a university degree or vocational training can dramatically increase earning potential, leading to financial independence and a better quality of life for the individual and their children. However, the role of education is often complicated by systemic inequities. If schools in low-income areas receive less funding or offer lower-quality instruction than those in affluent areas, education can reinforce existing inequalities rather than overcome them. Therefore, the **quality, accessibility, and equity** of the entire educational system—from early childhood to higher education—are critical determinants of a society's overall level of social mobility. Policies aimed at reducing achievement gaps and providing financial aid are essential to ensure education fulfills its promise as a pathway to upward mobility."
  },
  {
    "topic": "Key Leadership Qualities Essential for Effective Teams",
    "tags": [
      "leadership",
      "management",
      "teamwork",
      "psychology",
      "business"
    ],
    "content": "Effective leadership in modern teams requires a mix of traditional and adaptive qualities focused on empowering individuals and navigating change. One of the most essential qualities is **Vision and Clarity**: the ability to articulate a compelling future state for the team and ensure every member understands how their work contributes to that goal. This provides purpose. Second is **Empathy and Emotional Intelligence (EQ)**: understanding the team members' feelings, motivations, and stressors. Leaders with high EQ can manage conflict, foster a psychologically safe environment, and tailor their communication style to the individual. Third is **Decisiveness and Accountability**: while consensus is often sought, a leader must be able to make a final, timely decision under pressure and take ownership of the outcome, whether positive or negative. Fourth is **Humility and Continuous Learning**: admitting mistakes, seeking feedback, and prioritizing the growth of the team over personal ego. Finally, **Delegation** is crucial; good leaders distribute authority and trust their team to execute, freeing themselves up for strategic work. A combination of these qualities creates a climate of trust, motivation, and high performance."
  },
  {
    "topic": "Ethical Considerations and Governance in Modern Technology",
    "tags": [
      "ethics",
      "technology",
      "ai",
      "society",
      "governance"
    ],
    "content": "Ethics in technology address the moral principles that govern the design, development, and deployment of technological artifacts, especially those with societal impact (like AI, social media, and data collection). As technology scales rapidly, its potential for unintended harm also grows, making ethical governance vital. Core concerns include **Bias in Algorithms**: AI systems trained on biased data can perpetuate or amplify discrimination in areas like lending, hiring, or criminal justice. **Privacy and Data Sovereignty**: The collection and use of massive amounts of personal data raise concerns about surveillance, manipulation, and security breaches. **Accountability**: Determining who is responsible when an autonomous system (like a self-driving car or a diagnostic AI) causes harm. Ethical principles often involve establishing systems that are Transparent (how they work), Fair (no unjust bias), and Accountable. The solution requires a multi-stakeholder approach involving engineers, philosophers, policymakers, and regulators to create robust ethical frameworks and governance mechanisms. The goal is to ensure technological progress is aligned with human values and serves the broader public good rather than solely commercial interests."
  },
  {
    "topic": "The Balance Between Long-Term and Short-Term Thinking",
    "tags": [
      "psychology",
      "strategy",
      "decision-theory",
      "business",
      "planning"
    ],
    "content": "Effective decision-making requires balancing the immediate needs of **short-term thinking** with the strategic goals of **long-term thinking**. Short-term thinking focuses on immediate results, quarterly earnings, urgent crises, and near-term gratification. It is necessary for survival and responsiveness in a fast-changing environment. However, an over-reliance on short-term thinking can lead to chronic underinvestment in essential areas (R&D, infrastructure, employee training) and an erosion of brand trust, ultimately cannibalizing future success for current gain. Long-term thinking prioritizes strategic vision, sustainable value creation, and resilience, even at the cost of short-term losses (e.g., investing in a product that won't yield profit for five years). The human brain often defaults to short-term thinking due to the psychological principle of **Hyperbolic Discounting**, where the value of a reward drops sharply the further away it is in the future. Successful individuals and organizations actively employ structures—like establishing multi-year roadmaps, setting clear values, and using long-term compensation incentives—to override this default and ensure today's actions build toward a desirable, resilient future rather than merely reacting to the present."
  }
]

# %%
# for i in data:
#     tags = ",".join(i['tags'])
#     print(tags)

# %%
for i in data:
    tags = ",".join(i['tags'])
    topic = i["topic"]
    content = i['content']
    r = requests.post("http://localhost:3000/api/note?userId=693d7c690255969eec107464", json= {"topic": topic, "tags": i['tags'], "content": content})
    note_id = r.json()['message']
    print(note_id)
    # e = requests.get("http://127.0.0.1:8000")
    e = requests.post("http://127.0.0.1:8000/save_embeddings", json={ "note_id": str(note_id), "user_id": "693d7c690255969eec107464", "topic": str(topic), "tags": str(tags), "content": str(content) })
    print("Status Code:", e.status_code)
    print("Response Headers:", e.headers)
    print("Response Text:", e.text)
    # print(e.json()['note_id'])
# Out:
# 693fb758b4baf47c10b5924b
# Status Code: 200
# Response Headers: {'date': 'Mon, 15 Dec 2025 07:23:03 GMT', 'server': 'uvicorn', 'content-length': '94', 'content-type': 'application/json'}
# Response Text: {"status":"success","note_id":"693fb758b4baf47c10b5924b","user_id":"693d7c690255969eec107464"}
# 693fb759b4baf47c10b5924d
# Status Code: 200
# Response Headers: {'date': 'Mon, 15 Dec 2025 07:23:04 GMT', 'server': 'uvicorn', 'content-length': '94', 'content-type': 'application/json'}
# Response Text: {"status":"success","note_id":"693fb759b4baf47c10b5924d","user_id":"693d7c690255969eec107464"}
# 693fb759b4baf47c10b5924f
# Status Code: 200
# Response Headers: {'date': 'Mon, 15 Dec 2025 07:23:04 GMT', 'server': 'uvicorn', 'content-length': '94', 'content-type': 'application/json'}
# Response Text: {"status":"success","note_id":"693fb759b4baf47c10b5924f","user_id":"693d7c690255969eec107464"}
# 693fb759b4baf47c10b59251
# Status Code: 200
# ...

# %%
r.text
